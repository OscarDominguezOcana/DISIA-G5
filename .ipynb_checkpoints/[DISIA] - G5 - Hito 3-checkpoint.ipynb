# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("/kaggle/input/cupids-algorithm/cupid_algorithm_dataset.csv")

# %%
df.head()
# Out:
#    pair_id  a_age  a_education a_location    a_career_field  \
# 0        1     46            3   Suburban        Healthcare
# 1        2     32            2   Suburban              Tech
# 2        3     25            4      Rural         Marketing
# 3        4     38            4   Suburban           Finance
# 4        5     36            2      Rural  Entrepreneurship
#
#    a_career_ambition  a_openness  a_extraversion  a_agreeableness  \
# 0               0.23        0.67            0.78             0.32
# 1               0.58        0.78            0.70             0.51
# 2               0.59        0.33            0.87             0.64
# 3               0.54        0.34            0.28             0.72
# 4               0.56        0.35            0.62             0.27
#
#    a_conscientiousness  ...  b_extraversion  b_agreeableness  \
# 0                 0.49  ...            0.61             0.67
# 1                 0.71  ...            0.31             0.20
# 2                 0.82  ...            0.30             0.49
# 3                 0.81  ...            0.35             0.46
# 4                 0.73  ...            0.66             0.45
#
#   b_conscientiousness  b_chronotype  b_spontaneity  b_love_language  \
# 0                0.50          0.20           0.19     Quality Time
# 1                0.57          0.45           0.56   Physical Touch
# 2                0.43          0.84           0.74   Physical Touch
# 3                0.21          0.80           0.35  Receiving Gifts
# 4                0.43          0.86           0.36  Acts of Service
#
#   b_emotional_expressiveness compatibility_score  compatible  \
# 0                       0.73                43.5           0
# 1                       0.84                60.4           0
# 2                       0.48                74.3           1
# 3                       0.41                58.0           0
# 4                       0.50                69.8           1
#
#    relationship_longevity_months
# 0                             60
# 1                             59
# 2                             84
# 3                             70
# 4                             68
#
# [5 rows x 30 columns]

# %%
df['a_career_field'].value_counts()
# Out:
# a_career_field
# Finance             10169
# Engineering         10045
# Education           10043
# Law                 10036
# Creative Arts        9997
# Entrepreneurship     9981
# Tech                 9964
# Healthcare           9957
# Marketing            9951
# Science              9857
# Name: count, dtype: int64

# %%
df['a_love_language'].value_counts()
# Out:
# a_love_language
# Words of Affirmation    20160
# Quality Time            20095
# Receiving Gifts         19991
# Physical Touch          19888
# Acts of Service         19866
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# pair_id                          0
# a_age                            0
# a_education                      0
# a_location                       0
# a_career_field                   0
# a_career_ambition                0
# a_openness                       0
# a_extraversion                   0
# a_agreeableness                  0
# a_conscientiousness              0
# a_chronotype                     0
# a_spontaneity                    0
# a_love_language                  0
# a_emotional_expressiveness       0
# b_age                            0
# b_education                      0
# b_location                       0
# b_career_field                   0
# b_career_ambition                0
# b_openness                       0
# b_extraversion                   0
# b_agreeableness                  0
# b_conscientiousness              0
# b_chronotype                     0
# b_spontaneity                    0
# b_love_language                  0
# b_emotional_expressiveness       0
# compatibility_score              0
# compatible                       0
# relationship_longevity_months    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (100000, 30)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   pair_id                        100000 non-null  int64
#  1   a_age                          100000 non-null  int64
#  2   a_education                    100000 non-null  int64
#  3   a_location                     100000 non-null  object
#  4   a_career_field                 100000 non-null  object
#  5   a_career_ambition              100000 non-null  float64
#  6   a_openness                     100000 non-null  float64
#  7   a_extraversion                 100000 non-null  float64
#  8   a_agreeableness                100000 non-null  float64
#  9   a_conscientiousness            100000 non-null  float64
#  10  a_chronotype                   100000 non-null  float64
#  11  a_spontaneity                  100000 non-null  float64
#  12  a_love_language                100000 non-null  object
#  13  a_emotional_expressiveness     100000 non-null  float64
#  14  b_age                          100000 non-null  int64
#  15  b_education                    100000 non-null  int64
#  16  b_location                     100000 non-null  object
#  17  b_career_field                 100000 non-null  object
#  18  b_career_ambition              100000 non-null  float64
#  19  b_openness                     100000 non-null  float64
#  20  b_extraversion                 100000 non-null  float64
#  21  b_agreeableness                100000 non-null  float64
#  22  b_conscientiousness            100000 non-null  float64
#  23  b_chronotype                   100000 non-null  float64
#  24  b_spontaneity                  100000 non-null  float64
#  25  b_love_language                100000 non-null  object
#  26  b_emotional_expressiveness     100000 non-null  float64
#  27  compatibility_score            100000 non-null  float64
#  28  compatible                     100000 non-null  int64
#  29  relationship_longevity_months  100000 non-null  int64
# dtypes: float64(17), int64(7), object(6)
# memory usage: 22.9+ MB

# %%
object_cols = df.select_dtypes(include='object').columns

# %%
df = pd.get_dummies(df, columns=object_cols, dtype='int8',drop_first=False)

# %%
df.shape
# Out:
# (100000, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 60 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   pair_id                               100000 non-null  int64
#  1   a_age                                 100000 non-null  int64
#  2   a_education                           100000 non-null  int64
#  3   a_career_ambition                     100000 non-null  float64
#  4   a_openness                            100000 non-null  float64
#  5   a_extraversion                        100000 non-null  float64
#  6   a_agreeableness                       100000 non-null  float64
#  7   a_conscientiousness                   100000 non-null  float64
#  8   a_chronotype                          100000 non-null  float64
#  9   a_spontaneity                         100000 non-null  float64
#  10  a_emotional_expressiveness            100000 non-null  float64
#  11  b_age                                 100000 non-null  int64
#  12  b_education                           100000 non-null  int64
#  13  b_career_ambition                     100000 non-null  float64
#  14  b_openness                            100000 non-null  float64
#  15  b_extraversion                        100000 non-null  float64
#  16  b_agreeableness                       100000 non-null  float64
#  17  b_conscientiousness                   100000 non-null  float64
#  18  b_chronotype                          100000 non-null  float64
#  19  b_spontaneity                         100000 non-null  float64
#  20  b_emotional_expressiveness            100000 non-null  float64
#  21  compatibility_score                   100000 non-null  float64
#  22  compatible                            100000 non-null  int64
#  23  relationship_longevity_months         100000 non-null  int64
#  24  a_location_Rural                      100000 non-null  int8
#  25  a_location_Suburban                   100000 non-null  int8
#  26  a_location_Urban                      100000 non-null  int8
#  27  a_career_field_Creative Arts          100000 non-null  int8
#  28  a_career_field_Education              100000 non-null  int8
#  29  a_career_field_Engineering            100000 non-null  int8
#  30  a_career_field_Entrepreneurship       100000 non-null  int8
#  31  a_career_field_Finance                100000 non-null  int8
#  32  a_career_field_Healthcare             100000 non-null  int8
#  33  a_career_field_Law                    100000 non-null  int8
#  34  a_career_field_Marketing              100000 non-null  int8
#  35  a_career_field_Science                100000 non-null  int8
#  36  a_career_field_Tech                   100000 non-null  int8
#  37  a_love_language_Acts of Service       100000 non-null  int8
#  38  a_love_language_Physical Touch        100000 non-null  int8
#  39  a_love_language_Quality Time          100000 non-null  int8
#  40  a_love_language_Receiving Gifts       100000 non-null  int8
#  41  a_love_language_Words of Affirmation  100000 non-null  int8
#  42  b_location_Rural                      100000 non-null  int8
#  43  b_location_Suburban                   100000 non-null  int8
#  44  b_location_Urban                      100000 non-null  int8
#  45  b_career_field_Creative Arts          100000 non-null  int8
#  46  b_career_field_Education              100000 non-null  int8
#  47  b_career_field_Engineering            100000 non-null  int8
#  48  b_career_field_Entrepreneurship       100000 non-null  int8
#  49  b_career_field_Finance                100000 non-null  int8
#  50  b_career_field_Healthcare             100000 non-null  int8
#  51  b_career_field_Law                    100000 non-null  int8
#  52  b_career_field_Marketing              100000 non-null  int8
#  53  b_career_field_Science                100000 non-null  int8
#  54  b_career_field_Tech                   100000 non-null  int8
#  55  b_love_language_Acts of Service       100000 non-null  int8
#  56  b_love_language_Physical Touch        100000 non-null  int8
#  57  b_love_language_Quality Time          100000 non-null  int8
#  58  b_love_language_Receiving Gifts       100000 non-null  int8
#  59  b_love_language_Words of Affirmation  100000 non-null  int8
# dtypes: float64(17), int64(7), int8(36)
# memory usage: 21.7 MB

# %%
cor=df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(cor, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
X = df.drop(columns='compatible')
y = df['compatible']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.feature_selection import mutual_info_regression

mutual_info = mutual_info_regression(X_train, y_train)

# %%
mutual_info
# Out:
# array([3.26801727e-03, 2.63123438e-03, 0.00000000e+00, 3.12506295e-03,
#        0.00000000e+00, 2.96515905e-03, 1.87593111e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.32437591e-03, 0.00000000e+00,
#        1.53998998e-03, 3.72658428e-03, 2.94086290e-03, 4.50583983e-03,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.36001025e-03, 6.85262146e-01, 1.12119737e-01, 6.87680559e-04,
#        0.00000000e+00, 0.00000000e+00, 1.69490617e-03, 7.42466898e-03,
#        1.02884912e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.34575399e-04, 0.00000000e+00, 1.32677217e-04, 1.65782372e-03,
#        2.00516624e-03, 3.88961755e-03, 0.00000000e+00, 1.37565428e-03,
#        0.00000000e+00, 2.71450417e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.95187597e-03, 2.64592140e-03, 2.63979950e-03,
#        1.09567101e-03, 4.70870983e-03, 3.62451358e-03, 0.00000000e+00,
#        1.07557396e-03, 2.09469485e-03, 7.63210963e-04, 0.00000000e+00,
#        1.81932092e-03, 1.47142870e-03, 0.00000000e+00])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mi=mutual_info.sort_values(ascending=False).head(39)
mi
# Out:
# compatibility_score                0.685262
# relationship_longevity_months      0.112120
# a_career_field_Education           0.007425
# b_career_field_Healthcare          0.004709
# b_extraversion                     0.004506
# b_career_field_Education           0.003952
# a_love_language_Physical Touch     0.003890
# b_career_ambition                  0.003727
# b_career_field_Law                 0.003625
# a_emotional_expressiveness         0.003324
# pair_id                            0.003268
# a_career_ambition                  0.003125
# a_extraversion                     0.002965
# b_openness                         0.002941
# b_location_Rural                   0.002715
# b_career_field_Engineering         0.002646
# b_career_field_Entrepreneurship    0.002640
# a_age                              0.002631
# b_emotional_expressiveness         0.002360
# b_career_field_Tech                0.002095
# a_love_language_Acts of Service    0.002005
# a_agreeableness                    0.001876
# b_love_language_Quality Time       0.001819
# a_career_field_Creative Arts       0.001695
# a_career_field_Tech                0.001658
# b_education                        0.001540
# b_love_language_Receiving Gifts    0.001471
# a_love_language_Receiving Gifts    0.001376
# b_career_field_Finance             0.001096
# b_career_field_Science             0.001076
# a_career_field_Engineering         0.001029
# a_career_field_Law                 0.000935
# b_love_language_Acts of Service    0.000763
# a_location_Rural                   0.000688
# a_career_field_Science             0.000133
# a_openness                         0.000000
# a_conscientiousness                0.000000
# a_chronotype                       0.000000
# a_education                        0.000000
# dtype: float64

# %%
top_features = mi.index

# %%
X_train = X_train[top_features]
X_test = X_test[top_features]

# %%
c=X_train.corr()
plt.figure(figsize=(15,15))
sns.heatmap(c, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

cr=classification_report(y_test,y_pred)
accu=accuracy_score(y_test,y_pred)
cm=confusion_matrix(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     17163
#            1       0.69      0.71      0.70     12837
#
#     accuracy                           0.74     30000
#    macro avg       0.74      0.74      0.74     30000
# weighted avg       0.74      0.74      0.74     30000

# %%
print(accu)
# Out:
# 0.7408333333333333

# %%
print(cm)
# Out:
# [[13056  4107]
#  [ 3668  9169]]
